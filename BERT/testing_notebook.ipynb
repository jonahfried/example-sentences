# %%
import json
import pandas as pd

# %%
with open("../example_sentences.json") as file:
    sentences_from_json = json.load(file)

# %%
example_sentences = {
    word:[sentence_data["sentence"]["string"].replace("\t", " ") for sentence_data in sentences]
    for (word, sentences) 
    in sentences_from_json.items()
}

# %%
example_sentences["david"]
# Out:
# ['David escaped.',
#  'The Dutch explorer and entrepreneur David Pietersz.',
#  'One example is a line of aftershave and fragrances called David Beckham Instinct.',
#  'Sobel is the niece of journalist Ruth Gruber and the cousin of epidemiologist David Michaels.  ',
#  'David returns to Ziklag.']

# %%
word_sentence_pairs = []

# %%
for word, lst in example_sentences.items():
    for sentence in lst:
        word_sentence_pairs.append((word, sentence))

# %%
data = pd.DataFrame(word_sentence_pairs)

# %%
data.to_csv(path_or_buf="train.tsv", sep="\t", index=False)

# %%
pd.read_csv("train.tsv", sep="\t")
# Out:
#                 0                                                  1
# 0           david                                     David escaped.
# 1           david  The Dutch explorer and entrepreneur David Piet...
# 2           david  One example is a line of aftershave and fragra...
# 3           david  Sobel is the niece of journalist Ruth Gruber a...
# 4           david                           David returns to Ziklag.
# 5       described  The B-tree uses all of the ideas described above.
# 6       described  Molecular diffusion is typically described mat...
# 7       described            He was a self-described "jumping robot.
# 8       described  Based upon different combinations of changes, ...
# 9       described  Informally, a relational database relation is ...
# 10         hebrew  Another is that it is related to the Hebrew wo...
# 11         hebrew  The word Druzes, in an early Hebrew edition of...
# 12         hebrew  The word "" ("Druzes") occurs in an early Hebr...
# 13         hebrew  David  David () is described in the Hebrew Bib...
# 14         hebrew  Steven McKenzie, Associate Professor of the He...
# 15          bible  Ancient Near East historians generally doubt t...
# 16          bible  Jay Curry Treat states on the dating of Barnab...
# 17          bible  Some deists rejected the claim of Jesus' divin...
# 18          bible  The text in the Bible does not explicitly stat...
# 19          bible  His mother is not named in any book of the Bib...
# 20           king  An adjacent island holds the remains of Hovgår...
# 21           king  Danes attacked Birka, accompanied with the dep...
# 22           king  Jonathan meets with David again and confirms h...
# 23           king  With the First Dynasty, the capital moved from...
# 24           king  Following an endorsement by horror writer Step...
# 25         united                                Manchester United
# 26         united  TEM-26 are among the most common in the United...
# 27         united  When this occurs, the soul is united with the ...
# 28         united  As leader of the united East, Diocletian was c...
# 29         united  The findings were published in "Proceedings of...
# ...           ...                                                ...
# 61403        nifl  In the United Kingdom, it is traditional for a...
# 61404    fixtures  In rugby league, festive fixtures were a stapl...
# 61405    fixtures  Prior to the formation of leagues, a number of...
# 61406    fixtures  Since the transition to a summer season in the...
# 61407    llanelli  Prior to the formation of leagues, a number of...
# 61408   wakefield  Since the transition to a summer season in the...
# 61409     cricket  In Australia, New Zealand and South Africa, Te...
# 61410      hobart  In Australia, the first day of the Boxing Day ...
# 61411       yacht  In Australia, the first day of the Boxing Day ...
# 61412     kempton  In horse racing, there is the King George VI C...
# 61413     kempton  In addition to the prestigious race at Kempton...
# 61414  racecourse  In horse racing, there is the King George VI C...
# 61415  cheltenham  It is the second most prestigious chase in Bri...
# 61416    barbados  In Barbados, the final day of horse racing is ...
# 61417    savannah  In Barbados, the final day of horse racing is ...
# 61418    foxhound  Boxing Day is one of the main days in the hunt...
# 61419     harrier  Boxing Day is one of the main days in the hunt...
# 61420     beagles  Boxing Day is one of the main days in the hunt...
# 61421     bassets  Boxing Day is one of the main days in the hunt...
# 61422        iihf  The IIHF World U20 Championship typically begi...
# 61423    spengler  The IIHF World U20 Championship typically begi...
# 61424    spengler  The IIHF World U20 Championship typically begi...
# 61425       davos  The IIHF World U20 Championship typically begi...
# 61426       davos  The IIHF World U20 Championship typically begi...
# 61427       slate  The National Hockey League traditionally had c...
# 61428  bargaining  However, the 2013 collective bargaining agreem...
# 61429      malawi  In some African Commonwealth nations, particul...
# 61430      zambia  In some African Commonwealth nations, particul...
# 61431      guyana  This practice has also been followed for decad...
# 61432       bandy  A notable tradition in Sweden is "", which for...
#
# [61433 rows x 2 columns]
